-- %% [markdown]
-- Rename the column

-- %%
USE UnitTesting;
GO
ALTER TABLE Person 
ALTER COLUMN Email VARCHAR(20) NULL

-- %% [markdown]
-- Run all the tests

-- %%
EXEC tSQLt.RunAll;

-- %% [markdown]
-- Put it all back in place

-- %%
USE UnitTesting;
GO
ALTER TABLE Person 
ALTER COLUMN Email VARCHAR(100) NOT NULL

-- %% [markdown]
-- Run all the tests

-- %%
EXEC tSQLt.RunAll;
